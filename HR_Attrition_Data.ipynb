# %% [markdown]
# ## HR Analytics
#
# An Introduction
#
# Definition HR analytics is the process of collecting and analyzing Human Resource (HR) data in order to improve an organization’s workforce performance.
# The process can also be referred to as talent analytics, people analytics, or even workforce analytics.
# This method of data analysis takes data that is routinely collected by HR and correlates it to HR and organizational objectives.
# Doing so provides measured evidence of how HR initiatives are contributing to the organization’s goals and strategies.
#
# Need of HR Analytics Most organizations already have data that is routinely collected, so why the need for a specialized form of analytics? Can HR not simply look at the data they already have? Unfortunately,
# raw data on its own cannot actually provide any useful insight.
# It would be like looking at a large spreadsheet full of numbers and words.
# Once organized, compared and analyzed, this raw data provides useful insight.They can help answer questions like:
#
# What patterns can be revealed in employee turnover?
# How long does it take to hire employees?
# What amount of investment is needed to get employees up to a fully productive speed?
# Which of our employees are most likely to leave within the year?
# Are learning and development initiatives having an impact on employee performanc
#
# The process of HR Analytics
#
# HR Analytics is made up of several components that feed into each other.
#
# To gain the problem-solving insights that HR Analytics promises, data must first be collected.
# The data then needs to be monitored and measured against other data, such as historical information, norms or averages.
# This helps identify trends or patterns. It is at this point that the results can be analyzed at the analytical stage.
# The final step is to apply insight to organizational decisions.

# %% [markdown]
# ### Importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt


# %matplotlib inline

# %%
data = pd.read_csv('D:\Internships\TCR Innovation\Assignments\Final Projects\HR_Employee_Attrition-1.csv')

# %%
data
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0                  1       Yes   41      Travel_Rarely       1102
# 1                  2        No   49  Travel_Frequently        279
# 2                  3       Yes   37      Travel_Rarely       1373
# 3                  4        No   33  Travel_Frequently       1392
# 4                  5        No   27      Travel_Rarely        591
# ...              ...       ...  ...                ...        ...
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
data.head()
# Out:
#    EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0               1       Yes   41      Travel_Rarely       1102
# 1               2        No   49  Travel_Frequently        279
# 2               3       Yes   37      Travel_Rarely       1373
# 3               4        No   33  Travel_Frequently       1392
# 4               5        No   27      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                         1            80
# ...

# %%
data.tail()
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 2935  Research & Development                23          2        Medical
# 2936  Research & Development                 6          1        Medical
# 2937  Research & Development                 4          3  Life Sciences
# 2938                   Sales                 2          3        Medical
# 2939  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# ## Data Description

# %%
data.shape
# Out:
# (2940, 35)

# %%
data.describe()
# Out:
#        EmployeeNumber          Age    DailyRate  DistanceFromHome  \
# count     2940.000000  2940.000000  2940.000000       2940.000000
# mean      1470.500000    36.923810   802.485714          9.192517
# std        848.849221     9.133819   403.440447          8.105485
# min          1.000000    18.000000   102.000000          1.000000
# 25%        735.750000    30.000000   465.000000          2.000000
# 50%       1470.500000    36.000000   802.000000          7.000000
# 75%       2205.250000    43.000000  1157.000000         14.000000
# max       2940.000000    60.000000  1499.000000         29.000000
#
#          Education  EmployeeCount  EnvironmentSatisfaction   HourlyRate  \
# count  2940.000000         2940.0              2940.000000  2940.000000
# mean      2.912925            1.0                 2.721769    65.891156
# std       1.023991            0.0                 1.092896    20.325969
# min       1.000000            1.0                 1.000000    30.000000
# ...

# %% [markdown]
# ## Checking for null values

# %%
data.isnull().sum()
# Out:
# EmployeeNumber              0
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            2940 non-null   int64
#  1   Attrition                 2940 non-null   object
#  2   Age                       2940 non-null   int64
#  3   BusinessTravel            2940 non-null   object
#  4   DailyRate                 2940 non-null   int64
#  5   Department                2940 non-null   object
#  6   DistanceFromHome          2940 non-null   int64
#  7   Education                 2940 non-null   int64
#  8   EducationField            2940 non-null   object
#  9   EmployeeCount             2940 non-null   int64
#  10  EnvironmentSatisfaction   2940 non-null   int64
#  11  Gender                    2940 non-null   object
#  12  HourlyRate                2940 non-null   int64
#  13  JobInvolvement            2940 non-null   int64
# ...

# %% [markdown]
# ## Explanatory Data Analysis

# %%
attrition_count = pd.DataFrame(data['Attrition'].value_counts())
attrition_count
# Out:
#      Attrition
# No        2466
# Yes        474

# %%
plt.pie(attrition_count['Attrition'] , labels = ['No' , 'Yes'] , explode = (0.2,0))
# Out:
# ([<matplotlib.patches.Wedge at 0x20ce38b4e50>,
# ...
#  [Text(-1.136781068348268, 0.6306574368426737, 'No'),
#   Text(0.961891673217765, -0.5336332157899547, 'Yes')])

# %%
sns.countplot(data['Attrition'])
# Out:
# C:\Anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Attrition', ylabel='count'>

# %% [markdown]
# ## Numerical Analysis of dataset

# %%
data.hist(edgecolor='black',linewidth=1,figsize=(20,20))
plt.show()

# %% [markdown]
# ## Categorical Analysis

# %%
plt.figure(figsize=(20,20))

plt.subplot(3,3,1)
sns.countplot(x='BusinessTravel', hue='Attrition',data=data,palette='spring')

plt.subplot(3,3,2)
sns.countplot(x='Department', hue='Attrition',data=data,palette='summer')

plt.subplot(3,3,3)
sns.countplot(x='EducationField', hue='Attrition',data=data,palette='spring')
plt.xticks(rotation=90)

plt.subplot(3,3,4)
sns.countplot(x='Gender', hue='Attrition',data=data,palette='summer')

plt.subplot(3,3,5)
sns.countplot(x='JobRole', hue='Attrition',data=data,palette='spring')
plt.xticks(rotation=90)

plt.subplot(3,3,6)
sns.countplot(x='MaritalStatus', hue='Attrition',data=data,palette='summer')

plt.subplot(3,3,7)
sns.countplot(x='OverTime', hue='Attrition',data=data,palette='spring')

plt.show()

# %% [markdown]
# # Observation:
#
# BusinessTravel: Employees, who travel frequesntly more likly to quit than other employee.
#
# Department: Research & Development department employee more likely to stay than other department.
#
# Education Field: The employees with 'Medical' & 'life science' are more likely to stay, on the other hand the employess with 'Marketing' & 'Technical Degree'having more chances to quit their job.
#
# Gender: Male attrition rate is more than Female.
#
# JobRole: The jobrole having 'Sales executive','Sales representative','Laboratory Technician'are more likely to quit their jobs.
#
# MaritalStatus: The 'Married' employees are more likely to stay in job other than 'Single' & 'Divorce'.
#
# Overtime: The employees who work more hours are likely to quit than others.

# %% [markdown]
# ## Dropping columns

# %%
data = data.drop(columns=['StandardHours','EmployeeCount'])

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(25,25))
sns.heatmap(data.corr(),annot=True,cmap='Blues')
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['Age'],kde = False);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = 'MaritalStatus',y = 'PerformanceRating',data = data);

# %% [markdown]
# ### On average the marital status does not has any effect in Work Performance

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Attrition',y = 'DistanceFromHome',data = data);

# %% [markdown]
# ### Employees who attrited had their homes farther than rest of the employees

# %%
plt.figure(figsize=(10,6))
sns.distplot(data['DailyRate'],kde = False);
# Out:
# C:\Anaconda\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### The DailyRate for all the employees is almost Uniform

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Attrition',y = 'EnvironmentSatisfaction',data = data);

# %% [markdown]
# ### Its obvious that attrited employees where dissatisfied with their work environments

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Attrition',y = 'MonthlyIncome',data = data);

# %% [markdown]
# ## The attrited employees had lower Monthly Income than others but there are many outliers

# %%
plt.figure(figsize=(10,6))
sns.boxplot(y = 'Attrition',x = 'YearsAtCompany',data = data);

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Education',y = 'MonthlyIncome',data = data);

# %% [markdown]
# ### Higher levels of education tends to Higher Income

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'BusinessTravel',y = 'PerformanceRating',data = data)
# Out:
# <AxesSubplot:xlabel='BusinessTravel', ylabel='PerformanceRating'>

# %% [markdown]
# ### Bussiness Travels have no effect on Performance

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Education',y = 'PerformanceRating',data = data)
# Out:
# <AxesSubplot:xlabel='Education', ylabel='PerformanceRating'>

# %% [markdown]
# ### Looks like the level of education has not much to add to the Work Performance

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Gender',y = 'MonthlyIncome',data = data);

# %% [markdown]
# ### The Monthly Income of Female Employees at IBM is more than male employees

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Gender',y = 'JobSatisfaction',data = data);

# %% [markdown]
# ### Job Satisfaction of male employees is slightly better than female employees

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'RelationshipSatisfaction', y = 'PerformanceRating',data = data);

# %% [markdown]
# ### Like Marital Status, Relationship Satisfaction too has nothing to do with Job Performance

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'JobSatisfaction', y = 'JobRole',data = data)
# Out:
# <AxesSubplot:xlabel='JobSatisfaction', ylabel='JobRole'>

# %% [markdown]
# ### On Average Healthcare Representatives are the most and HR Employees are the least satisfied employees

# %%
plt.figure(figsize=(20,6))
sns.barplot(x = 'YearsAtCompany', y = 'JobSatisfaction',data = data);

# %%
sns.boxplot(y = 'OverTime', x = 'PercentSalaryHike',data = data);

# %% [markdown]
# ### Overtime isn't likely to get you an increase in salary

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'MaritalStatus', y = 'Education',data = data);

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'Department', y = 'JobInvolvement',data = data);

# %% [markdown]
# ### All the Departments are equally involved at work!!

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'StockOptionLevel', y = 'NumCompaniesWorked',data = data);

# %% [markdown]
# ### The more company an employee has worked with the more stock options he/she has

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'PerformanceRating', y = 'DistanceFromHome',data = data);

# %% [markdown]
# ### Distance of an employee's home from office has no effect in his/her performance

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x = 'JobSatisfaction', y = 'DistanceFromHome',data = data);

# %% [markdown]
# ### Similarly Distance from home does not affcet Job Satisfaction

# %%
data.hist(bins=50, figsize=(25,15))
plt.show()

# %% [markdown]
# ## Data preprocessing

# %%
from sklearn.preprocessing import LabelEncoder
for column in data.columns:
    if data[column].dtype==np.number:
        continue
    else:
        data[column]=LabelEncoder().fit_transform(data[column])
# Out:
# <ipython-input-56-a1bc78649650>:3: DeprecationWarning: Converting `np.inexact` or `np.floating` to a dtype is deprecated. The current result is `float64` which is not strictly correct.
#   if data[column].dtype==np.number:

# %% [markdown]
# ### Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
rf = RandomForestClassifier(n_estimators = 10, criterion = 'entropy', random_state = 0)

# %%
x  = data.drop(['Attrition'], axis = 1)
y = data['Attrition']

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 0)

# %%
x_train.head()
# Out:
#       EmployeeNumber  Age  BusinessTravel  DailyRate  Department  \
# 2755            2755   28               0        474           2
# 2451            2451   17               1        361           2
# 391              391   22               2        284           1
# 1885            1885   16               1        123           2
# 220              220   18               2        823           1
#
#       DistanceFromHome  Education  EducationField  EnvironmentSatisfaction  \
# 2755                25          1               1                        1
# 2451                17          3               2                        3
# 391                  1          2               3                        1
# 1885                 5          1               2                        3
# 220                  4          1               1                        3
#
#       Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# ...

# %%
x_train.shape
# Out:
# (2058, 32)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10, random_state=0)

# %%
rf.score(x_train, y_train)
# Out:
# 0.9956268221574344

# %% [markdown]
# ### predicting for  x_test

# %%
pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, pred)
# Out:
# 0.9319727891156463

# %%
print(accuracy_score(y_test,pred))
# Out:
# 0.9319727891156463

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.96       737
#            1       0.97      0.61      0.75       145
#
#     accuracy                           0.93       882
#    macro avg       0.95      0.80      0.85       882
# weighted avg       0.93      0.93      0.93       882

# %%
sns.heatmap(confusion_matrix(y_test,pred),cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ### DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predict_tree=tree.predict(x_test)

# %%
print(accuracy_score(y_test,predict_tree))
# Out:
# 0.9285714285714286

# %%
print(classification_report(y_test,predict_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.96       737
#            1       0.80      0.75      0.78       145
#
#     accuracy                           0.93       882
#    macro avg       0.88      0.86      0.87       882
# weighted avg       0.93      0.93      0.93       882

# %%
sns.heatmap(confusion_matrix(y_test,predict_tree),cmap='viridis',annot=True)
plt.show()

# %% [markdown]
# ### Random Forest with 100 estimators

# %%
from sklearn.ensemble import RandomForestClassifier
rfc_100 = RandomForestClassifier(n_estimators=100)

# %%
rfc_100.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
rfc_100_predict= rfc_100.predict(x_test)

# %%
print(accuracy_score(y_test,rfc_100_predict))
# Out:
# 0.963718820861678

# %%
print(classification_report(y_test,rfc_100_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98       737
#            1       0.99      0.79      0.88       145
#
#     accuracy                           0.96       882
#    macro avg       0.98      0.89      0.93       882
# weighted avg       0.96      0.96      0.96       882

# %%
sns.heatmap(confusion_matrix(y_test,rfc_100_predict),cmap='seismic',annot=True)
plt.show()

# %% [markdown]
# ### Random Forest with No estimators

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predict_rfc=rfc.predict(x_test)

# %%
print(accuracy_score(y_test,predict_rfc))
# Out:
# 0.9546485260770975

# %%
print(classification_report(y_test,predict_rfc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97       737
#            1       0.96      0.75      0.84       145
#
#     accuracy                           0.95       882
#    macro avg       0.96      0.87      0.91       882
# weighted avg       0.96      0.95      0.95       882

# %%
sns.heatmap(confusion_matrix(y_test,predict_rfc),cmap='cubehelix',annot=True)
plt.show()

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log= LogisticRegression()
log.fit(x_train, y_train)
# Out:
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
predictions = log.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.8401360544217688

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.99      0.91       737
#            1       0.64      0.06      0.11       145
#
#     accuracy                           0.84       882
#    macro avg       0.74      0.53      0.51       882
# weighted avg       0.81      0.84      0.78       882

# %%
sns.heatmap(confusion_matrix(y_test,predictions),cmap='viridis',annot=True)
plt.show()
